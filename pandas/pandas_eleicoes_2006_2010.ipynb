# %% [markdown]
# # Brincando com Pandas

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/home/lsp/dados/am/eleicoes_2006_a_2010.csv')
data[:3]
# Out:
#     ano  sequencial_candidato                             nome  uf partido  \
# 0  2006                 10001      JOSÉ LUIZ NOGUEIRA DE SOUSA  AP      PT
# 1  2006                 10002                LOIVA DE OLIVEIRA  RO      PT
# 2  2006                 10002  MARIA DALVA DE SOUZA FIGUEIREDO  AP      PT
#
#    quantidade_doacoes  quantidade_doadores  total_receita  media_receita  \
# 0                   6                    6        16600.0    2766.666667
# 1                  13                   13        22826.0    1755.846154
# 2                  17                   16       148120.8    9257.550000
#
#    recursos_de_outros_candidatos/comites  ...    quantidade_despesas  \
# 0                                    NaN  ...                     14
# 1                                 6625.0  ...                     24
# 2                                 2250.0  ...                    123
#
#    quantidade_fornecedores  total_despesa  media_despesa             cargo  \
# ...

# %% [markdown]
# É possível configurar a forma de ler um arquivo, como em:
#
# `file = pd.read_csv('file.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')`
#
# Mudando o separador para **;**
# O encoding para **latin1**
# E configurando o formato da data

# %% [markdown]
# ### Pausa para algumas dicas:
#
# Verificando o tipo do objeto e os métodos e atributos disponíveis

# %%
type(data)
dir(data)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
# ...

# %% [markdown]
# Obter ajuda em um notebook

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# Ver a lista de funções mágicas do notebook

# %%
# %quickref

# %% [markdown]
# # Voltando

# %% [markdown]
# ### Selecionando colunas

# %%
data[['nome', 'votos']]
# Out:
#                                   nome   votos
# 0          JOSÉ LUIZ NOGUEIRA DE SOUSA    8579
# 1                    LOIVA DE OLIVEIRA    2757
# 2      MARIA DALVA DE SOUZA FIGUEIREDO   17428
# 3                       ROMALDO MILANI    1193
# 4               ANSELMO DE JESUS ABREU   29401
# 5       JOSÉ RODRIGUES DOS SANTOS NETO    1822
# 6                  JOSÉ TOMAZ DA SILVA     317
# 7             LUIZ CARLOS MUNHOZ MEIRA    2591
# 8                  EDILSON VEIRA ROCHA    2551
# 9        EDUARDO VALVERDE ARAÚJO ALVES   34631
# 10                    IRINEU RODRIGUES   26856
# 11            TARCISIO JOÃO ZIMERMMANN  106659
# 12               WILLIAN GOMES EUGENIO    1859
# 13            AMAURI GUEDES DE FREITAS    3752
# 14                  ELIAS RAMOS SOARES    8346
# 15       FRANCISCO ALVES DA CRUZ FILHO    4621
# 16          GILBERTO JOSÉ SPIER VARGAS  124686
# 17                 GLAYDSTON LIRA GOES     609
# 18                   ISAAC SILVA GOMES      88
# ...

# %% [markdown]
# ### Selecionando as colunas nome e votos e apenas as 5 primeiras linhas

# %%
data[['nome', 'votos']][:5]
# Out:
#                               nome  votos
# 0      JOSÉ LUIZ NOGUEIRA DE SOUSA   8579
# 1                LOIVA DE OLIVEIRA   2757
# 2  MARIA DALVA DE SOUZA FIGUEIREDO  17428
# 3                   ROMALDO MILANI   1193
# 4           ANSELMO DE JESUS ABREU  29401

# %% [markdown]
# ### Ordenando os dados

# %%
data.sort_values(['ano', 'votos'], ascending=False)[:5]
# Out:
#        ano  sequencial_candidato  \
# 6532  2010          250000001352
# 5669  2010          190000002498
# 6980  2010          250000002829
# 6716  2010          250000001880
# 5915  2010          210000000191
#
#                                                nome  uf  partido  \
# 6532              FRANCISCO EVERARDO OLIVEIRA SILVA  SP       PR
# 5669  ANTHONY WILLIAN GAROTINHO MATHEUS DE OLIVEIRA  RJ       PR
# 6980                GABRIEL BENEDITO ISSAAC CHALITA  SP      PSB
# 6716                              PAULO SALIM MALUF  SP       PP
# 5915                   MANUELA PINTO VIEIRA D AVILA  RS  PC do B
#
#       quantidade_doacoes  quantidade_doadores  total_receita  media_receita  \
# 6532                  41                   32      673383.13   21043.222813
# 5669                 236                  161     2442612.27   15171.504783
# 6980                 124                  107     2080738.19   19446.151308
# ...

# %% [markdown]
# ### Contando os valores comuns de um atributo

# %% [markdown]
# #### Agrupando por sexo

# %%
data['sexo'].value_counts()
# Out:
# MASCULINO    6305
# FEMININO     1025
# Name: sexo, dtype: int64

# %% [markdown]
# #### Agrupando por nível de escolaridade

# %%
data['grau'].value_counts()
# Out:
# SUPERIOR COMPLETO                4255
# ENSINO MÉDIO COMPLETO            1435
# SUPERIOR INCOMPLETO               803
# ENSINO FUNDAMENTAL COMPLETO       432
# ENSINO MÉDIO INCOMPLETO           192
# ENSINO FUNDAMENTAL INCOMPLETO     183
# LÊ E ESCREVE                       30
# Name: grau, dtype: int64

# %% [markdown]
# #### Agrupando por partido

# %%
data['partido'].value_counts()
# Out:
# PT         606
# PMDB       574
# PV         526
# PDT        503
# PSB        485
# PSDB       477
# PTB        403
# PPS        329
# PP         323
# PSOL       299
# PSC        276
# PMN        258
# PTC        245
# PHS        218
# PFL        180
# PC do B    161
# DEM        158
# PSL        155
# PL         154
# PR         138
# PT do B    127
# PRTB       125
# PRB        111
# PSDC       109
# PRP        107
# PTN         91
# PRONA       77
# PAN         54
# PSTU        41
# PCB         14
# PCO          6
# Name: partido, dtype: int64

# %% [markdown]
# #### Agrupando por ocupação

# %%
data['ocupacao'].value_counts()
# Out:
# OUTROS                                                           819
# DEPUTADO                                                         703
# ADVOGADO                                                         673
# EMPRESÁRIO                                                       629
# VEREADOR                                                         326
# MÉDICO                                                           325
# COMERCIANTE                                                      316
# SERVIDOR PÚBLICO ESTADUAL                                        248
# SERVIDOR PÚBLICO FEDERAL                                         214
# PROFESSOR DE ENSINO MÉDIO                                        172
# ADMINISTRADOR                                                    160
# ENGENHEIRO                                                       158
# APOSENTADO (EXCETO SERVIDOR PÚBLICO)                             153
# POLICIAL MILITAR                                                 149
# ...

# %% [markdown]
# #### Agrupando pelo ano da eleição

# %%
data['ano'].value_counts()
# Out:
# 2010    3942
# 2006    3388
# Name: ano, dtype: int64

# %% [markdown]
# ## Separando dados das eleições

# %%
eleicao_2006 = data[(data.ano==2006)]
eleicao_2010 = data[(data.ano==2010)]

# %% [markdown]
# ### Agrupando dados de 2006 por partido e sexo

# %%
dist_sexo_partido = eleicao_2006.groupby(['partido', 'sexo']).size().reset_index(name="quantidade")
dist_sexo_partido
# Out:
#     partido       sexo  quantidade
# 0       PAN   FEMININO           4
# 1       PAN  MASCULINO          50
# 2   PC do B   FEMININO          15
# 3   PC do B  MASCULINO          43
# 4       PCB  MASCULINO           3
# 5       PCO  MASCULINO           3
# 6       PDT   FEMININO          28
# 7       PDT  MASCULINO         248
# 8       PFL   FEMININO          19
# 9       PFL  MASCULINO         161
# 10      PHS   FEMININO          12
# 11      PHS  MASCULINO          76
# 12       PL   FEMININO          14
# 13       PL  MASCULINO         140
# 14     PMDB   FEMININO          30
# 15     PMDB  MASCULINO         245
# 16      PMN   FEMININO          12
# 17      PMN  MASCULINO          91
# 18       PP   FEMININO          10
# 19       PP  MASCULINO         135
# 20      PPS   FEMININO          23
# 21      PPS  MASCULINO         185
# 22      PRB   FEMININO           2
# 23      PRB  MASCULINO          12
# 24    PRONA   FEMININO          20
# 25    PRONA  MASCULINO          57
# ...

# %%
dist_sexo_partido = data.groupby(['ano', 'partido', 'sexo']).size().reset_index(name="quantidade")
dist_sexo_partido.sort_values('partido')
# Out:
#       ano  partido       sexo  quantidade
# 56   2010      DEM  MASCULINO         146
# 55   2010      DEM   FEMININO          12
# 0    2006      PAN   FEMININO           4
# 1    2006      PAN  MASCULINO          50
# 2    2006  PC do B   FEMININO          15
# 3    2006  PC do B  MASCULINO          43
# 58   2010  PC do B  MASCULINO          81
# 57   2010  PC do B   FEMININO          22
# 59   2010      PCB  MASCULINO          11
# 4    2006      PCB  MASCULINO           3
# 5    2006      PCO  MASCULINO           3
# 61   2010      PCO  MASCULINO           2
# 60   2010      PCO   FEMININO           1
# 62   2010      PDT   FEMININO          33
# 63   2010      PDT  MASCULINO         194
# 6    2006      PDT   FEMININO          28
# 7    2006      PDT  MASCULINO         248
# 8    2006      PFL   FEMININO          19
# 9    2006      PFL  MASCULINO         161
# 10   2006      PHS   FEMININO          12
# 11   2006      PHS  MASCULINO          76
# ...

# %%
dis
